# %%
import numpy as np
import os

# %%
ls = os.listdir("/data2/lzylzy/mimic_feature_set_c2/subjects")
int(ls[1])
# Out:
# 3903

# %%
v = np.load(os.path.join( '/home/lzy/KDD-MIMIC/mimic_feature_set_c/resources/res/admission_ids.npy'), allow_pickle=True).tolist()
admission_ids = v['admission_ids']

# %%
type(admission_ids[1])
# Out:
# int

# %%
# Out:
# [44377,
#  30367,
#  44743,
#  46126,
#  45431,
#  46236,
#  42866,
#  46805,
#  41619,
#  44127,
#  41669,
#  30052,
#  225893,
#  42574,
#  46708,
#  43904,
#  44568,
#  45459,
#  42596,
#  44728,
#  42756,
#  41693,
#  46266,
#  45939,
#  30317,
#  45741,
#  45454,
#  30373,
#  45719,
#  30351,
#  41733,
#  45476,
#  44573,
#  46683,
#  46585,
#  45287,
#  42879,
#  46651,
#  41176,
#  43032,
#  42265,
#  44559,
#  44396,
#  42396,
#  42422,
#  45563,
#  46486,
#  44515,
#  44695,
#  42166,
#  45038,
#  45721,
#  30388,
#  46594,
#  46063,
#  45149,
#  42849,
#  45906,
#  45218,
#  45114,
#  30004,
#  43979,
#  42286,
#  30001,
#  42731,
#  227529,
#  46045,
#  42408,
#  46009,
#  44116,
#  30030,
#  42647,
#  42275,
#  41807,
#  30027,
#  46654,
#  226453,
#  45989,
#  45298,
#  221833,
#  42917,
#  44339,
#  42477,
#  43014,
#  43170,
#  43141,
#  45777,
#  45926,
#  46362,
#  42845,
#  41828,
#  42110,
#  30075,
#  46005,
#  42812,
#  45990,
#  46298,
#  30399,
#  44123,
# ...

# %%
str(225210) in valid_input
# Out:
# False
